# %% [markdown]
# <div style="text-align:center"><img src="../mu_images/idsi_logo.png" alt="MU Institute for Data Science &amp; Informatics" width="280" style="display:inline-block;margin:0 auto"></div>

# %% [markdown]
# # Module 3: Multiple Systems, Entanglement, and Interference
#
# ## Description
#
# One qubit helps us understand basic quantum information. The multiple systems allows us to explain more quantum principles and more advanced mathematics. This module extends the notation to composite systems via the tensor product, which is where the exponential scaling of the state space appears. Entanglement and interference, the two resources that make quantum algorithms work, are introduced here, along with quantum teleportation.
#
# ----

# %% [markdown]
# ## Guiding Questions
#
# What is quantum entanglement, how do these systems scale exponentially, and what does quantum teleportation mean?

# %% [markdown]
# ## Topics Covered
#
# - Tensor products and multi-qubit state vectors
# - Exponential scaling of the state space
# - Entanglement and the Bell states
# - Interference as a computational resource
# - Quantum teleportation
# - Transpilation, shot count, simulator vs. real hardware

# %% [markdown]
# ## Objectives
#
# - Students will construct multi-qubit states using the tensor product
# - Students will distinguish product states from entangled states
# - Students will prepare a Bell state and interpret its measurement statistics
# - Students will explain the role of interference in a quantum algorithm
# - Students will describe what transpilation does and why shot count matters

# %% [markdown]
# ## Material
#
# 1. [Multiple Systems](https://learning.quantum.ibm.com/course/basics-of-quantum-information/multiple-systems) (64 min)
# 1. [IBM Transpilation](https://quantum.cloud.ibm.com/docs/en/guides/transpile)
#
# ### Optional
#
# 1. [Entanglement in Action](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/entanglement-in-action/introduction)
# 1. [Quantum Teleportation](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/entanglement-in-action/quantum-teleportation)

# %% [markdown]
# ## Slides
#
# 1. [Measurement and Entanglement](resources/M3_Measurement_and_Entanglement_slides.ipynb)

# %% [markdown]
# ## Assignments
#
# 1. [Quantum Composer Lab](exercises/M3_E1_Quantum_Composer_Lab.ipynb)
# 1. [Introduction to Qiskit Lab](exercises/M3_E2_Intro_to_Qiskit_Lab.ipynb)

# %% [markdown]
# ## Module Quiz
#
# * [Module 3 Practice Quiz](practices/M3_Quiz.ipynb)
#
# **Course requirement:** you must score **9/10 or higher (90%)** on at least one module's practice quiz. Each quiz draws 10 random questions from a larger bank and tells you the moment you've met the requirement; you can re-roll for a fresh set as often as you like.

# %% [markdown]
# ## IBM Badge Progress
#
# This module counts toward: **Basics of Quantum Information (Weeks 2-4)**
#
# Practice exam for this badge:
#
# * [Basics of Quantum Information Practice Exam](../badge_exams/Basics_of_Quantum_Information_Practice_Exam.ipynb)
#
# Badges are earned through IBM Quantum Learning directly. See [Start_Here](../Start_Here.ipynb) for the full badge map and your practice-exam progress.

# %% [markdown]
# ## Submitting Your Work
#
# Be sure you have submitted your assignments for Module 3.
#  * See [Submission of Work](../module1/labs/M1_L3_Committing_Work.ipynb) in Module 1.
#
# It is best practice to create a save point (commit) after each interval of work, e.g., when you are done for the day or you have completed a notebook.
