# %% [markdown]
# # Measurement and Entanglement: Slides
#
# *Module 3 slide deck, converted from PowerPoint.* Each slide is shown as an image; the text beneath it is extracted from the slide for search and reference.
#
# Source deck: `M3_Measurement_and_Entanglement.pptx`
#
# ---

# %% [markdown]
# ## Slide 1: Measurement and Entanglement
#
# ![Slide 1](M3_Measurement_and_Entanglement_slides_images/Slide1.PNG)
#
# ---

# %% [markdown]
# ## Slide 2: Topics
#
# ![Slide 2](M3_Measurement_and_Entanglement_slides_images/Slide2.PNG)
#
# > Measurement
# > Observables
# > Entanglement
# > Using a book analogy
# > Using a coin analogy
#
# ---

# %% [markdown]
# ## Slide 3: Measurement
#
# ![Slide 3](M3_Measurement_and_Entanglement_slides_images/Slide3.PNG)
#
# ---

# %% [markdown]
# ## Slide 4: Measurement Coin
#
# ![Slide 4](M3_Measurement_and_Entanglement_slides_images/Slide4.PNG)
#
# ---

# %% [markdown]
# ## Slide 5: Measuring after a circuit
#
# ![Slide 5](M3_Measurement_and_Entanglement_slides_images/Slide5.PNG)
#
# ---

# %% [markdown]
# ## Slide 6: Measurement Fundamentally Changes the State
#
# ![Slide 6](M3_Measurement_and_Entanglement_slides_images/Slide6.PNG)
#
# ---

# %% [markdown]
# ## Slide 7: Observable
#
# ![Slide 7](M3_Measurement_and_Entanglement_slides_images/Slide7.PNG)
#
# ---

# %% [markdown]
# ## Slide 8: What are those “Observable Strings” in Qiskit
#
# ![Slide 8](M3_Measurement_and_Entanglement_slides_images/Slide8.PNG)
#
# > You see a string like “IZZX” as an observable.
# > What does that mean?
# > What are you measuring?
# > What does -1 mean?
# > What does 1 mean?
#
# ---

# %% [markdown]
# ## Slide 9: First let’s look at one qubit
#
# ![Slide 9](M3_Measurement_and_Entanglement_slides_images/Slide9.PNG)
#
# ---

# %% [markdown]
# ## Slide 10: What about two qubits?
#
# ![Slide 10](M3_Measurement_and_Entanglement_slides_images/Slide10.PNG)
#
# > The observable is like splitting all possibilities into two sets of possibilities
# > It can be calculated by  multiplying the eigenvalues of each individual observable
#
# ---

# %% [markdown]
# ## Slide 11: Calculating Observable Value by String
#
# ![Slide 11](M3_Measurement_and_Entanglement_slides_images/Slide11.PNG)
#
# ---

# %% [markdown]
# ## Slide 12: What does entanglement look like?
#
# ![Slide 12](M3_Measurement_and_Entanglement_slides_images/Slide12.PNG)
#
# ---

# %% [markdown]
# ## Slide 13: Entanglement comes from Superposition
#
# ![Slide 13](M3_Measurement_and_Entanglement_slides_images/Slide13.PNG)
#
# ---
