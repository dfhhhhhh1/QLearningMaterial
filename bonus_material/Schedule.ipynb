# %% [markdown]
# # Bonus Material
#
# ## Description
#
# Expand on material covered in this course to introduce other quantum machine types (trapped ion, neutral atom, photonic, annealing), future algorithms, and fault-tolerant schemas including qLDPC codes.
#
# ----

# %% [markdown]
# ## Topics Covered
#
# - Trapped-ion quantum computers
# - Neutral-atom quantum computers
# - Photonic quantum computers
# - Quantum annealing
# - Future algorithms
# - Fault-tolerant schemas, including qLDPC codes

# %% [markdown]
# ## Material
#
# *Links TBD.*

# %% [markdown]
# ## A Note on This Module
#
# This material is optional and ungraded. It is here for participants who finish the eight-week sequence and want to know what is beyond the IBM superconducting stack the course is built on.
