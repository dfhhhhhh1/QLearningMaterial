# %% [markdown]
# <div style="text-align:center"><img src="mu_images/idsi_logo.png" alt="MU Institute for Data Science &amp; Informatics" width="280" style="display:inline-block;margin:0 auto"></div>

# %% [markdown]
# # Welcome to Mizzou's QLearning Buddies 8-Week Course
#
# ## This is an 8-Week introduction to bring you from beginner to practitioner using IBM Quantum Learning resources
#
# This course introduces you to quantum computing from the ground up. Over eight weeks, you will
# explore the essential mathematical concepts, quantum circuits, and Qiskit programming needed to
# work with real quantum hardware, then extend into error correction, utility-scale practice, and
# current research.
#
# Two ideas drive how this course is built:<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;1) **Quantum computing is learned by running things.** Most modules have both assignments through the notebooks and
# conceptual materials. The mathematics is an important early component of this course;
# you will use it, in code, against a simulator and against real quantum hardware.<BR>
# &nbsp;&nbsp;&nbsp;&nbsp;2) **Being able to understand and critically evaluate quantum claims is an important skill to learn from this course.** A great deal is claimed about quantum computing. By the end of this course you
# should be able to read a claim about quantum advantage, a hardware roadmap, or an algorithmic
# speedup, and tell what it actually says. The last assignment requires you do analyze a project of your choosing for quantum integration in this exact way.
#
# By the end of the course you should understand core quantum mechanics principles, have Qiskit
# installed and working, and be able to program a real quantum computer.
#
# **Expected effort: 3-4 hours per week.**
#
# -----

# %% [markdown]
# ### Course Module Schedule
#
# 1. [Quantum Fundamentals & Environment Setup](./module1/Schedule.ipynb)
# 2. [Quantum Mathematics and Notations with Linear Algebra](./module2/Schedule.ipynb)
# 3. [Multiple Systems, Entanglement, and Interference](./module3/Schedule.ipynb)
# 4. [Qiskit Programming and Circuits](./module4/Schedule.ipynb)
# 5. [Quantum Algorithm Exploration](./module5/Schedule.ipynb)
# 6. [Quantum Error Correction and Fault-Tolerant Quantum](./module6/Schedule.ipynb)
# 7. [Quantum in Practice and Scaling to Utility](./module7/Schedule.ipynb)
# 8. [Current Research and Future Planning](./module8/Schedule.ipynb)
# * [Bonus Material](./optional_material/Schedule.ipynb) *(optional, ungraded)*
#
# -----

# %% [markdown]
# ### Run the cell below to generate an 8 week timeline. Try to keep to these dates for quiz/assignment completion

# %%
import os
from datetime import datetime, timedelta
from IPython.display import display, HTML

# 1. Define the course schedule derived from Start_Here.md
_SCHEDULE_DATA = [
    {"num": "1", "title": "Quantum Fundamentals & Environment Setup", "link": "./module1/Schedule.ipynb"},
    {"num": "2", "title": "Quantum Mathematics and Notations with Linear Algebra", "link": "./module2/Schedule.ipynb"},
    {"num": "3", "title": "Multiple Systems, Entanglement, and Interference", "link": "./module3/Schedule.ipynb"},
    {"num": "4", "title": "Qiskit Programming and Circuits", "link": "./module4/Schedule.ipynb"},
    {"num": "5", "title": "Quantum Algorithm Exploration", "link": "./module5/Schedule.ipynb"},
    {"num": "6", "title": "Quantum Error Correction and Fault-Tolerant Quantum", "link": "./module6/Schedule.ipynb"},
    {"num": "7", "title": "Quantum in Practice and Scaling to Utility", "link": "./module7/Schedule.ipynb"},
    {"num": "8", "title": "Current Research and Future Planning", "link": "./module8/Schedule.ipynb"},
    {"num": "*", "title": "Bonus Material (optional, ungraded)", "link": "./optional_material/Schedule.ipynb"}
]

# 2. Calculate the schedule dates based on today
start_date = datetime.now()

_rows = []
for i, mod in enumerate(_SCHEDULE_DATA):
    if mod["num"] != "*":
        # Calculate start and end dates (assuming 1-week modules)
        mod_start = start_date + timedelta(weeks=i)
        mod_end = mod_start + timedelta(days=6)
        date_str = f"{mod_start.strftime('%b %d')} - {mod_end.strftime('%b %d')}"
        mod_col = f"Module {mod['num']}"
    else:
        date_str = "Ongoing"
        mod_col = "Bonus"
        
    # Generate styled HTML rows
    _rows.append(
        f'<tr style="border-bottom:1px solid #ddd">'
        f'<td style="padding:6px 12px;font-weight:600">{mod_col}</td>'
        f'<td style="padding:6px 12px"><a href="{mod["link"]}" style="text-decoration:none;color:#1976d2">{mod["title"]}</a></td>'
        f'<td style="padding:6px 12px;text-align:center;color:#424242">{date_str}</td>'
        f'</tr>'
    )

# 3. Build the final HTML output using the course's established styling
_banner_text = "Your Personalized 8-Week Course Schedule"

_html = (
    f'<div style="padding:10px 12px;border-radius:6px;background:#eef3fb;border:1px solid #5472ae;'
    f'color:#2b3f66;font-weight:700;max-width:820px;margin-bottom:10px">{_banner_text}</div>'
    '<table style="border-collapse:collapse;font-size:14px;width:100%;max-width:820px;text-align:left">'
    '<tr style="border-bottom:1px solid #bbb;background:#f5f5f5">'
    '<th style="padding:6px 12px">Module</th>'
    '<th style="padding:6px 12px">Topic</th>'
    '<th style="padding:6px 12px;text-align:center">Tentative Dates</th></tr>'
    + "".join(_rows) + "</table>"
)

# 4. Render the widget
display(HTML(_html))

# %% [markdown]
# ### Weekly Module Download
#
# Each week the new module becomes available. You will use Git to acquire the module's learning
# activities. Clicking on a module above before its content is pulled is expected to give you a
# '404 Error'.
#
#  * **Note:** Module 1 is included with the initial course deployment.
#
# #### Steps:
# 1. Open Terminal in JupyterHub
# 2. Change into the course folder
# ```bash
# cd f26dsaQLearning*
# ```
# 3. Execute command:
# ```bash
# git pull --no-edit upstream master
# ```

# %% [markdown]
# ### Technologies
#
# - **Python Programming**
#     - `qiskit` - quantum circuit construction, transpilation, and execution
#     - `qiskit-ibm-runtime` - the Sampler and Estimator primitives, and access to real hardware
#     - `numpy` - the linear algebra underneath everything in this course
#     - `matplotlib` - circuit and state visualization, including the Bloch sphere
# - **[IBM Quantum Platform](https://quantum.cloud.ibm.com/)**
#     - [IBM Quantum Composer](https://quantum.cloud.ibm.com/composer) - build and inspect circuits visually
#     - IBM Quantum Platform/Lab - View quantum jobs and hardware availability
# - **[IBM Quantum Learning](https://quantum.cloud.ibm.com/learning/en)** - the source of the core reading and video material

# %% [markdown]
# ### Before Module 1: Accounts and Install
#
# You need two things in place before the first module's work will run:
#
# 1. **An IBMid**, which is your login for the IBM Quantum Platform. Free to create, with coordination with the University of Missouri. If you are asked to enter your credit card, you are most likely creating an account NOT through Mizzou.
# 2. **A working Qiskit install**, either locally or in the course JupyterHub environment.
#
# Both are walked through in
# [Creating an IBMid and Installing Qiskit](./module1/exercises/M1_E1_IBMid_and_Qiskit_Setup.ipynb),
# which is the Module 1 assignment.
#
# **Do not share your IBM Quantum API token.** It is tied to your account and your hardware quota.
# Never paste it into a notebook you commit, and never share it publicly. The setup
# notebook shows you how to store it safely.
#
# -----

# %% [markdown]
# ### Weekly Module Schedule
#
# Every module can be worked through at your own pace within the timeframe of the module. Modules
# are one week long. All material is released at the beginning of each module to allow you to work
# through the week and manage your time as needed.
#
# **Days 1-3**
#  - Readings
#  - Videos
#  - Labs
#  - Practices
#
# **Late week**
#
#  - Assignments
#
# Module practices and assignments need to be committed and pushed by the end of the week following
# the release of the material.
#
#
# #### **Practice quizzes.** Each module includes a short, self-graded practice quiz (`practices/M<N>_Quiz.ipynb`). **Course requirement:** you must **complete at least 6 of the 8 module quizzes**. A quiz counts as complete when you score **9/10 or higher (90%)** on it. Each quiz draws 10 random questions from a larger bank and turns green when you complete the module.
#
# #### **Badge practice exams.** Optional and ungraded: longer practice runs for the IBM badges live in [`badge_exams/`](./badge_exams/README.md), pooled across the weeks each badge covers. See the badge table further down.
# -----

# %% [markdown]
# ### Your Quiz Progress
#
# Run the cell below to see your best score on each module's practice quiz and how many you have completed. The **course requirement is to complete 6 of the 8 module quizzes** (a quiz is complete when you score 9/10 or higher). Your scores are saved automatically each time you submit a quiz.

# %%
import json, os
from IPython.display import display, HTML

NEEDED = 6   # complete this many of the 8 module quizzes
_MODULES = {
    1: "Quantum Fundamentals & Environment Setup",
    2: "Quantum Mathematics and Notations with Linear Algebra",
    3: "Multiple Systems, Entanglement, and Interference",
    4: "Qiskit Programming and Circuits",
    5: "Quantum Algorithm Exploration",
    6: "Quantum Error Correction and Fault-Tolerant Quantum",
    7: "Quantum in Practice and Scaling to Utility",
    8: "Current Research and Future Planning",
}
_prog = {}
if os.path.exists(".quiz_progress.json"):
    try:
        with open(".quiz_progress.json", encoding="utf-8") as _f:
            _prog = json.load(_f)
    except Exception:
        _prog = {}

_rows, _done = [], 0
for _n, _title in _MODULES.items():
    _e = _prog.get(str(_n))
    if _e:
        _s, _t = _e["best_score"], _e["best_total"]
        _met = _e.get("met", _s * 10 >= 9 * _t)
        _done += 1 if _met else 0
        _col = "#2e7d32" if _met else "#ef6c00"
        _status = "complete" if _met else "keep going"
        _score = f"{_s} / {_t}"
    else:
        _col, _status, _score = "#9e9e9e", "not attempted", "-"
    _rows.append(
        f'<tr><td style="padding:4px 12px">Module {_n}</td>'
        f'<td style="padding:4px 12px">{_title}</td>'
        f'<td style="padding:4px 12px;text-align:center">{_score}</td>'
        f'<td style="padding:4px 12px;color:{_col};font-weight:600">{_status}</td></tr>')

_ok = _done >= NEEDED
_bcol = "#2e7d32" if _ok else "#ef6c00"
_bbg = "#e6f4ea" if _ok else "#fff3e0"
if _ok:
    _banner = f"Course requirement MET: you have completed {_done} of 8 module quizzes ({NEEDED} needed)."
else:
    _banner = f"Completed {_done} of 8 module quizzes. Complete {NEEDED} to meet the course requirement."
_html = (
    f'<div style="padding:10px 12px;border-radius:6px;background:{_bbg};border:1px solid {_bcol};'
    f'color:{_bcol};font-weight:700;max-width:820px;margin-bottom:10px">{_banner}</div>'
    '<table style="border-collapse:collapse;font-size:14px">'
    '<tr style="border-bottom:1px solid #bbb">'
    '<th style="padding:4px 12px;text-align:left">Module</th>'
    '<th style="padding:4px 12px;text-align:left">Topic</th>'
    '<th style="padding:4px 12px">Best</th>'
    '<th style="padding:4px 12px">Status</th></tr>'
    + "".join(_rows) + "</table>")
display(HTML(_html))

# %% [markdown]
# ### IBM Course Badges
#
# Several modules map onto IBM Quantum Learning badges, which you earn through IBM directly and
# which are yours to keep independent of this course. They are not required, but the coursework
# lines up with them closely enough that you are most of the way there already.
#
# Each badge has a **practice exam** in [`badge_exams/`](./badge_exams/README.md). They work like
# the weekly quizzes, random draw, two attempts per set, and a **New questions** button, but they
# are longer (20 questions) and pooled across everything the badge covers.
# They are practice only, nothing here is graded and the badge itself is earned on IBM's site.
#
# | Badge | Covered by | Practice exam |
# |-------|------------|---------------|
# | [Basics of Quantum Information](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information) | Weeks 2-4 | [Practice exam](./badge_exams/Basics_of_Quantum_Information_Practice_Exam.ipynb) |
# | [Fundamentals of Quantum Algorithms](https://quantum.cloud.ibm.com/learning/en/courses/fundamentals-of-quantum-algorithms/exam) | Week 5 | [Practice exam](./badge_exams/Fundamentals_of_Quantum_Algorithms_Practice_Exam.ipynb) |
# | [Foundations of Quantum Error Correction](https://quantum.cloud.ibm.com/learning/en/courses/foundations-of-quantum-error-correction/exam) | Week 6 | [Practice exam](./badge_exams/Foundations_of_Quantum_Error_Correction_Practice_Exam.ipynb) |
# | [Quantum Business Foundations](https://quantum.cloud.ibm.com/learning/en/courses/quantum-business-foundations/exam) | Weeks 1, 5, 8 | [Practice exam](./badge_exams/Quantum_Business_Foundations_Practice_Exam.ipynb) |
#
# -----

# %% [markdown]
# ### Your Badge Practice Exam Progress
#
# Run the cell below to see your best score on each badge practice exam. These are **not** a
# course requirement, they are here to tell you whether you are ready to sit IBM's real exam.
# The pass mark shown is this course's own practice bar, check the badge page for the score IBM
# currently requires.

# %%
import json, os
from IPython.display import display, HTML

PASS_PCT = 75   # this course's practice bar, not IBM's
_BADGES = [
    ("badge:bqi", "Basics of Quantum Information", "Weeks 2-4",
     "badge_exams/Basics_of_Quantum_Information_Practice_Exam.ipynb"),
    ("badge:fqa", "Fundamentals of Quantum Algorithms", "Week 5",
     "badge_exams/Fundamentals_of_Quantum_Algorithms_Practice_Exam.ipynb"),
    ("badge:qec", "Foundations of Quantum Error Correction", "Week 6",
     "badge_exams/Foundations_of_Quantum_Error_Correction_Practice_Exam.ipynb"),
    ("badge:qbf", "Quantum Business Foundations", "Weeks 1, 5, 8",
     "badge_exams/Quantum_Business_Foundations_Practice_Exam.ipynb"),
]
_prog = {}
if os.path.exists(".quiz_progress.json"):
    try:
        with open(".quiz_progress.json", encoding="utf-8") as _f:
            _prog = json.load(_f)
    except Exception:
        _prog = {}

_rows, _passed = [], 0
for _key, _name, _weeks, _path in _BADGES:
    _e = _prog.get(_key)
    if not os.path.exists(_path):
        _col, _status, _score = "#9e9e9e", "not released yet", "-"
    elif _e:
        _s, _t = _e["best_score"], _e["best_total"]
        _pct = int(round(100 * _s / _t)) if _t else 0
        _met = _e.get("met", _pct >= PASS_PCT)
        _passed += 1 if _met else 0
        _col = "#2e7d32" if _met else "#ef6c00"
        _status = "ready for the IBM exam" if _met else "keep going"
        _score = f"{_s} / {_t}  ({_pct}%)"
    else:
        _col, _status, _score = "#9e9e9e", "not attempted", "-"
    _name_cell = _name if not os.path.exists(_path) else f'<a href="{_path}">{_name}</a>'
    _rows.append(
        f'<tr><td style="padding:4px 12px">{_name_cell}</td>'
        f'<td style="padding:4px 12px">{_weeks}</td>'
        f'<td style="padding:4px 12px;text-align:center">{_score}</td>'
        f'<td style="padding:4px 12px;color:{_col};font-weight:600">{_status}</td></tr>')

_banner = (f"Badge practice exams are optional and ungraded. You are at or above the {PASS_PCT}% "
           f"practice mark on {_passed} of {len(_BADGES)}.")
_html = (
    '<div style="padding:10px 12px;border-radius:6px;background:#eef3fb;border:1px solid #5472ae;'
    f'color:#2b3f66;font-weight:700;max-width:820px;margin-bottom:10px">{_banner}</div>'
    '<table style="border-collapse:collapse;font-size:14px">'
    '<tr style="border-bottom:1px solid #bbb">'
    '<th style="padding:4px 12px;text-align:left">Badge</th>'
    '<th style="padding:4px 12px;text-align:left">Covered by</th>'
    '<th style="padding:4px 12px">Best</th>'
    '<th style="padding:4px 12px">Status</th></tr>'
    + "".join(_rows) + "</table>")
display(HTML(_html))

# %% [markdown]
# ### The Ethic of Mutual Aid
#
# In each module it is important to ask and answer questions. All students should ask. Everyone
# should try to answer at least once. We learn by solving our own problems and helping others solve
# theirs.
#
# This matters more in quantum than in most subjects, because the field is genuinely
# counterintuitive. Nearly everyone hits a wall somewhere -- often at superposition, or at the
# tensor product, or at the moment measurement stops feeling like reading a value and starts feeling
# like a physical event. Hitting that wall is not a sign that you are behind. Saying so out loud is
# usually what gets you past it, and it helps the next person who hits the same wall.
#
# Mutual aid is a place to discuss the topic and the issue you are having. It is not a place to post
# code, working or not, for feedback or solutions. Posting code is counterproductive in this type of
# mutual aid environment.
#
# -----

# %% [markdown]
# ### Resources
#
# Each module has its own reading links, slide decks, and resources. Please consult the weekly
# `Schedule.ipynb` notebook for details and modular particulars.
#
# The core material for this course comes from **IBM Quantum Learning**
# (https://learning.quantum.ibm.com), which is free and publicly available. Module schedules link
# directly to the relevant lessons there.
