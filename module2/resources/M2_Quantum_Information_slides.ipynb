# %% [markdown]
# # Quantum Information: Slides
#
# *Module 2 slide deck, converted from PowerPoint.* Each slide is shown as an image; the text beneath it is extracted from the slide for search and reference.
#
# Source deck: `M2_Quantum_Information.pptx`
#
# ---

# %% [markdown]
# ## Slide 1: Quantum Information
#
# ![Slide 1](M2_Quantum_Information_slides_images/Slide1.PNG)
#
# ---

# %% [markdown]
# ## Slide 2: Low-level Classical Computing
#
# ![Slide 2](M2_Quantum_Information_slides_images/Slide2.PNG)
#
# > Binary Digit (bit)
# > Acts like an on/off switch
# > Takes value 0 or 1
# > Logic Gates
# > Act like actions or instructions on the bits
# > Such as OR, AND, NOT, and Addition
#
# ---

# %% [markdown]
# ## Slide 3: Quantum Gates
#
# ![Slide 3](M2_Quantum_Information_slides_images/Slide3.PNG)
#
# ---

# %% [markdown]
# ## Slide 4: Classic Gates
#
# ![Slide 4](M2_Quantum_Information_slides_images/Slide4.PNG)
#
# ---

# %% [markdown]
# ## Slide 5: Some Important Qubit States
#
# ![Slide 5](M2_Quantum_Information_slides_images/Slide5.PNG)
#
# ---

# %% [markdown]
# ## Slide 6: Some Important Quantum Gates
#
# ![Slide 6](M2_Quantum_Information_slides_images/Slide6.PNG)
#
# ---

# %% [markdown]
# ## Slide 7: Translating circuits to math
#
# ![Slide 7](M2_Quantum_Information_slides_images/Slide7.PNG)
#
# ---

# %% [markdown]
# ## Slide 8: Vector Tensor Product
#
# ![Slide 8](M2_Quantum_Information_slides_images/Slide8.PNG)
#
# ---

# %% [markdown]
# ## Slide 9: Tensor Product
#
# ![Slide 9](M2_Quantum_Information_slides_images/Slide9.PNG)
#
# ---

# %% [markdown]
# ## Slide 10
#
# ![Slide 10](M2_Quantum_Information_slides_images/Slide10.PNG)
#
# ---

# %% [markdown]
# ## Slide 11: Global Phase
#
# ![Slide 11](M2_Quantum_Information_slides_images/Slide11.PNG)
#
# ---

# %% [markdown]
# ## Slide 12: Unitary Properties
#
# ![Slide 12](M2_Quantum_Information_slides_images/Slide12.PNG)
#
# ---

# %% [markdown]
# ## Slide 13: Conjugate Transpose
#
# ![Slide 13](M2_Quantum_Information_slides_images/Slide13.PNG)
#
# ---
