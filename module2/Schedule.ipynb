# %% [markdown]
# <div style="text-align:center"><img src="../mu_images/idsi_logo.png" alt="MU Institute for Data Science &amp; Informatics" width="280" style="display:inline-block;margin:0 auto"></div>

# %% [markdown]
# # Module 2: Quantum Mathematics and Notations with Linear Algebra
#
# ## Description
#
# Quantum computing is linear algebra with a physical interpretation. This module builds the notation and the mathematical machinery you will use for the rest of the course: Dirac notation for states, unitary matrices for operations, and the Born rule for measurement. Superposition stops being a metaphor here and becomes a vector you can write down.
#
# ----

# %% [markdown]
# ## Guiding Questions
#
# How do I understand Dirac notation of quantum systems, why are unitary matrices important, what is superposition, and what does it mean to measure a quantum state?

# %% [markdown]
# ## Topics Covered
#
# - Dirac (bra-ket) notation
# - State vectors, amplitudes, and normalization
# - Unitary matrices and why reversibility matters
# - Superposition
# - Measurement and the Born rule
# - The Bloch sphere
# - The IBM Composer

# %% [markdown]
# ## Objectives
#
# - Students will read and write single-qubit states in Dirac notation
# - Students will explain why quantum operations must be unitary
# - Students will compute measurement probabilities from a state vector
# - Students will locate a single-qubit state on the Bloch sphere
# - Students will build and inspect a simple circuit in the IBM Composer

# %% [markdown]
# ## Material
#
# 1. [Single Systems](https://learning.quantum.ibm.com/course/basics-of-quantum-information/single-systems) (70 min)
# 1. [Revisiting Quantum Fundamentals](https://quantum.cloud.ibm.com/learning/en/modules/quantum-mechanics/get-started-with-qiskit)
# 1. [IBM Composer](https://quantum.ibm.com/composer/)
#
# ### Optional
#
# 1. [Superposition with Qiskit](https://quantum.cloud.ibm.com/learning/en/modules/quantum-mechanics/superposition-with-qiskit)

# %% [markdown]
# ## Slides
#
# 1. [Bloch Sphere and Phase](resources/M2_Bloch_Sphere_and_Phase_slides.ipynb)
# 1. [Quantum Information](resources/M2_Quantum_Information_slides.ipynb)

# %% [markdown]
# ## Demonstrations
#
# - IBM Composer / Jupyter notebook for gate testing and understanding
#
# Demonstrations are conducted live. Recordings and any supporting notebooks are posted to `resources/` after the session.

# %% [markdown]
# ## Assignments
#
# 1. [Quantum Computing Math Homework](exercises/M2_E1_Quantum_Math_Homework.ipynb)

# %% [markdown]
# ## Module Quiz
#
# * [Module 2 Practice Quiz](practices/M2_Quiz.ipynb)
#
# **Course requirement:** you must score **9/10 or higher (90%)** on at least one module's practice quiz. Each quiz draws 10 random questions from a larger bank and tells you the moment you've met the requirement; you can re-roll for a fresh set as often as you like.

# %% [markdown]
# ## IBM Badge Progress
#
# This module counts toward: **Basics of Quantum Information (Weeks 2-4)**
#
# Practice exam for this badge:
#
# * [Basics of Quantum Information Practice Exam](../badge_exams/Basics_of_Quantum_Information_Practice_Exam.ipynb)
#
# Badges are earned through IBM Quantum Learning directly. See [Start_Here](../Start_Here.ipynb) for the full badge map and your practice-exam progress.

# %% [markdown]
# ## Submitting Your Work
#
# Be sure you have submitted your assignments for Module 2.
#  * See [Submission of Work](../module1/labs/M1_L3_Committing_Work.ipynb) in Module 1.
#
# It is best practice to create a save point (commit) after each interval of work, e.g., when you are done for the day or you have completed a notebook.
