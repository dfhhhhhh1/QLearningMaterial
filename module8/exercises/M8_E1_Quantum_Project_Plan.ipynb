# %% [markdown]
# # Quantum Project Plan Development
#
# *Module 8 assignment, and the final assignment of the course.*
#
# Pick a project **of your own choosing** -- from your research, your job, a hobby, or a problem you
# have wanted an excuse to look at -- and write a plan for adding a quantum component to it that you
# could actually test.
#
# Fill in each section in the markdown cells provided. Section 3 also has a short code cell.

# %% [markdown]
# # Objective
#
# Everything in this course so far has handed you the problem. This one does not.
#
# The skill being assessed here is the one the course opened with: **telling the engineering from the
# hype.** By now you know what a qubit is, what a circuit costs, what noise does to it, and what
# kinds of structure quantum algorithms can exploit. The question is whether you can point that at a
# problem nobody has pre-screened for you and reach an honest conclusion.
#
# **An honest "no" is worth full credit.** If you work through your problem and conclude that quantum
# computing is a poor fit for it, say so, show the reasoning, and you have done the assignment
# correctly. A well-argued negative result is more valuable than an enthusiastic plan that ignores a
# fatal bottleneck. What is *not* worth credit is a plan that never engages with cost, encoding, or
# the classical baseline.
#
# ### Reference material
#
# - [How to become Quantum Ready](https://quantum.cloud.ibm.com/learning/en/courses/quantum-business-foundations/how-to-become-quantum-ready) (IBM Quantum Learning)
# - [Quantum Technology](https://quantum.cloud.ibm.com/learning/en/courses/quantum-business-foundations/quantum-technology) (IBM Quantum Learning)
# - [Quantum computing in practice](https://quantum.cloud.ibm.com/learning/en/courses/quantum-computing-in-practice) -- utility-scale workflow (IBM Quantum Learning)
# - [Introduction to primitives](https://quantum.cloud.ibm.com/docs/en/guides/primitives) -- Sampler vs Estimator (IBM docs)
# - [Error mitigation and suppression techniques](https://quantum.cloud.ibm.com/docs/en/guides/error-mitigation-and-suppression-techniques) (IBM docs)
# - [What's the difference between error suppression, mitigation, and correction?](https://www.ibm.com/quantum/blog/quantum-error-suppression-mitigation-correction) (IBM Research blog)
#
# **Length:** aim for roughly 1500-2500 words across all sections, plus the code cell and references.
# Quality of reasoning matters far more than word count.

# %% [markdown]
# ---
# # Section 1: The problem and its classical baseline
#
# Before any quantum content, establish what you are actually working on and what "already solved"
# looks like. Plans that skip this step tend to claim speedups over a competitor that was never
# measured.
#
# ***Answer the following:***
#
# 1. ***What is the problem?*** *Describe it in plain language, as you would to a colleague in a
#    different field. What are the inputs and what is the desired output?*
# 2. ***How is it solved today?*** *Name the actual classical method -- the algorithm, solver, or
#    software package. "By hand in a spreadsheet" is a legitimate answer if it is the true one.*
# 3. ***What does that currently cost?*** *Runtime, hardware, money, human hours -- whatever the
#    binding constraint is. Give real numbers if you have them and estimates if you do not, and say
#    which is which.*
# 4. ***What would "better" mean?*** *Faster? More accurate? Larger instances? Cheaper? Be specific,
#    because this is the target you will evaluate against in Section 6.*
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # Section 2: Why quantum might help -- or might not
#
# Quantum computers are not general-purpose accelerators. They help on problems with particular
# structure. The honest first question is whether yours has any of it.
#
# ***Which of these structures, if any, does your problem have? Argue for your answer.***
#
# | Structure | Typical quantum approach | Example |
# |---|---|---|
# | Simulating a quantum system | VQE, quantum simulation | molecular ground states, materials |
# | Combinatorial optimization | QAOA, annealing | scheduling, routing, portfolio selection |
# | Unstructured search over a huge space | Grover / amplitude amplification | constraint satisfaction |
# | Period finding / number theory | Shor, phase estimation | factoring, discrete log |
# | Sampling from a hard distribution | sampling algorithms | certain generative and statistical tasks |
# | Linear algebra on structured systems | HHL-family (largely fault-tolerant era) | some PDE and regression problems |
#
# ***Then answer directly:***
#
# 1. ***Which row (or rows) does your problem map onto, and how tightly?*** *If the mapping needs
#    heavy reformulation, say what the reformulation is.*
# 2. ***If none of them fit, say so plainly and explain why.*** *If that is your conclusion, the
#    remaining sections should describe what you investigated and what specifically ruled it out.
#    That is a complete and fully-credited answer.*
# 3. ***What is the strongest argument against your own proposal?*** *Make the case a skeptical
#    colleague would make.*
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # Section 3: Encoding your data
#
# This is where most quantum project proposals quietly fall apart, so it gets the most space.
#
# Before a quantum computer can do anything with your problem, the problem has to become qubits and
# gates. How you do that determines how many qubits you need, how deep the circuit is, and therefore
# whether it can run at all on present hardware.
#
# ## 3a: Compare the options
#
# | Encoding | Idea | Qubits for $N$ values | Watch out for |
# |---|---|---|---|
# | **Basis** | each bitstring is one value | $N$ bits to a register | no compression; wide registers |
# | **Amplitude** | data goes into the amplitudes of a state | $\log_2 N$ | exponentially compressed, but *preparing* the state can cost exponential depth |
# | **Angle / rotation** | one value per rotation gate | 1 qubit per feature (or reuse) | shallow and hardware-friendly; limited capacity |
# | **QUBO / Ising** | recast as minimizing a spin Hamiltonian | 1 qubit per binary variable | the standard route for optimization; constraints become penalty terms |
# | **Hamiltonian mapping** | fermions or spins mapped to Paulis (Jordan-Wigner, parity) | problem dependent | the chemistry route; watch the Pauli term count |
#
# ***Pick at least two of these that could plausibly apply to your problem and compare them.*** *For
# each: how many qubits would your real instance need, roughly how deep would the circuit be, and
# what breaks first as you scale up?*
#
# ## 3b: The loading bottleneck
#
# A trap worth naming explicitly, because it has sunk a lot of otherwise sensible proposals.
#
# If your problem involves a **large classical dataset**, ask how that data gets into the machine. An
# encoding that needs $O(N)$ gates to load $N$ numbers has already spent the speedup before the
# algorithm starts -- you cannot get an exponential advantage if merely reading the input takes
# exponential time. Amplitude encoding is the usual place this bites: the qubit count looks
# wonderful, and the state-preparation circuit is the thing that kills you.
#
# ***Does your problem have a data-loading bottleneck? If yes, how large is the data and what would
# loading it cost? If no, explain why it escapes the issue*** *(problems that generate their own
# structure from a compact description, such as a molecular Hamiltonian or a graph given by its edge
# list, often do).*
#
# ## 3c: Your choice
#
# ***Which encoding do you choose, and why? What are you giving up by choosing it?***
#
# **Your answers for 3a, 3b, and 3c:**
#
# *(write here)*

# %% [markdown]
# ## 3d: Proof-of-concept encoding
#
# Now make it concrete. Below is a runnable example of **angle encoding**: three data points, each
# turned into a rotation on its own qubit.
#
# ***Adapt this cell to your own problem.*** *Replace the sample values with 2-3 real data points from
# your project, adjust the encoding to match what you chose in 3c, and run it. If your chosen
# encoding is QUBO/Ising, build a small* `SparsePauliOp` *for a 2-3 variable instance instead. If it
# is basis encoding, prepare the bitstring.*
#
# ***Then state, in the markdown cell that follows, what the circuit represents and what would change
# if you scaled it to your full problem size.***

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# --- EXAMPLE: angle encoding of three feature values ---------------------------
# Replace these with real values from YOUR problem.
raw_values = [0.20, 0.85, 0.55]          # e.g. three normalized sensor readings

# Angle encoding maps each value v in [0, 1] to a rotation angle in [0, pi].
angles = [np.pi * v for v in raw_values]

qc = QuantumCircuit(len(angles))
for qubit, angle in enumerate(angles):
    qc.ry(angle, qubit)

print(qc.draw())
print(f"\nqubits used: {qc.num_qubits}   circuit depth: {qc.depth()}")

# What state did we actually build? (Only feasible to print for tiny examples.)
state = Statevector(qc)
probs = state.probabilities_dict()
print("\nlargest basis-state probabilities:")
for bits, p in sorted(probs.items(), key=lambda kv: -kv[1])[:4]:
    print(f"  |{bits}>  {p:.4f}")

# %% [markdown]
# ***What does your circuit represent, and what changes at full scale?***
#
# *(write here)*

# %% [markdown]
# ---
# # Section 4: Algorithm and primitive
#
# ***Answer the following:***
#
# 1. ***Which algorithm would you run?*** *VQE, QAOA, Grover, phase estimation, a sampling routine,
#    something else. Justify it from the structure you identified in Section 2, not from familiarity.*
# 2. ***Sampler or Estimator?*** *Recall from the Module 5 lab: the `Estimator` returns expectation
#    values of observables, and the `Sampler` returns measurement outcomes. Which does your algorithm
#    need, and why? (Optimization and chemistry routines usually want the Estimator; anything where
#    you need the bitstrings themselves wants the Sampler.)*
# 3. ***If it is variational, what is your ansatz and how many parameters does it have?*** *What
#    classical optimizer would you pair with it?*
# 4. ***Is this algorithm runnable on today's hardware, or does it assume error correction?*** *Be
#    honest: Grover and phase estimation at useful sizes are fault-tolerant-era algorithms.*
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # Section 5: Simulator versus real QPU
#
# ***Answer the following:***
#
# 1. ***What would you validate on a simulator first, and at what size?*** *A statevector simulator is
#    exact but limited to roughly 30 qubits before memory explodes. What is the largest instance you
#    could check this way, and what would you be checking -- correctness of the encoding, the
#    optimizer converging, the circuit compiling?*
# 2. ***What would make you move to real hardware?*** *Name the specific thing you could only learn
#    from a QPU. "It is more impressive" is not it.*
# 3. ***What will noise do to your results?*** *Which of error suppression, error mitigation, and
#    error correction applies at your scale? (Recall Module 6: correction needs far more physical
#    qubits than anything available today; mitigation is what runs now, and it costs extra shots.)*
# 4. ***Estimate your QPU budget.*** *Circuits x parameter values x shots. If it is a variational
#    algorithm, remember you need a fresh energy estimate at every optimizer step -- multiply
#    accordingly. Is the total plausible within a free-tier allocation?*
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # Section 6: Evaluating against classical
#
# A quantum result on its own means nothing. It has to be compared to something.
#
# ***Answer the following:***
#
# 1. ***What is your classical baseline, concretely?*** *The specific solver or method from Section 1,
#    run on specific hardware. Not "classical computers in general."*
# 2. ***What metric decides the comparison?*** *Solution quality, wall-clock time, energy accuracy,
#    approximation ratio, cost per solve. Pick the one that matters for your problem and defend it.*
# 3. ***What result would count as success?*** *State a number or a threshold, not a feeling.*
# 4. ***Utility or advantage?*** *Module 7 drew this distinction:* **quantum advantage** *means beating
#    every classical method, which is a very high bar and rarely claimed honestly;* **quantum
#    utility** *means the quantum machine did something useful at a scale where classical simulation
#    of it is hard.* ***Which are you actually aiming at?*** *(For a course project, utility is the
#    realistic target. Claiming advantage requires ruling out every good classical algorithm, which
#    is usually the hardest part of the whole enterprise.)*
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # Section 7: Resources and timeline
#
# ***Answer the following:***
#
# 1. ***Resource estimate.*** *Qubits, circuit depth after transpilation, shots per circuit, total
#    circuit executions. Rough is fine; show how you got there.*
# 2. ***Physical or logical?*** *If your algorithm needs error correction, note that a single logical
#    qubit currently costs on the order of hundreds to thousands of physical qubits, depending on the
#    code and the error rate. Restate your qubit requirement in physical terms if that applies.*
# 3. ***Where does this sit on the timeline?*** *Choose one and defend it:*
#    - *runnable today on available hardware*
#    - *runnable today but only at toy scale, with the useful scale still out of reach*
#    - *needs meaningful error mitigation improvements*
#    - *needs fault tolerance, so it is a research plan rather than an experiment*
# 4. ***What would you do first?*** *If you had one week and a free-tier account, what is step one?*
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # Section 8: Literature review
#
# ***Find 3-5 papers relevant to your proposed project and annotate each one.***
#
# Start at [arXiv quant-ph](https://arxiv.org/list/quant-ph/recent), and follow citations from the
# IBM course material you have already read. Google Scholar is fine for finding things; read at least
# the abstract, introduction, and conclusions of anything you cite.
#
# **For each paper, give:**
#
# 1. **Citation** -- authors, title, venue or arXiv number, year.
# 2. **What it claims** -- one or two sentences, in your own words.
# 3. **How it relates to your project** -- does it supply the encoding, the algorithm, the baseline,
#    or the cautionary tale?
# 4. **Demonstration or proposal?** -- *this one matters.* Did the authors **run** something and
#    report measured results, or did they **propose** a method and analyze it theoretically? Both are
#    legitimate science, but they support very different claims, and conflating them is exactly how
#    quantum computing gets over-sold. If it is a demonstration, note the problem size they actually
#    ran.
#
# Use a consistent citation format. Any standard style is fine as long as you stick to it.
#
# **Your literature review:**
#
# **Paper 1.**
# - *Citation:*
# - *What it claims:*
# - *How it relates:*
# - *Demonstration or proposal:*
#
# **Paper 2.**
# - *Citation:*
# - *What it claims:*
# - *How it relates:*
# - *Demonstration or proposal:*
#
# **Paper 3.**
# - *Citation:*
# - *What it claims:*
# - *How it relates:*
# - *Demonstration or proposal:*
#
# *(add papers 4 and 5 if you have them)*

# %% [markdown]
# ---
# # Section 9: Risks, open questions, and what would change your mind
#
# ***Answer the following:***
#
# 1. ***What are the three biggest risks to this project?*** *Technical, practical, or resource risks.*
# 2. ***What do you still not know?*** *Name the questions you could not answer while writing this.
#    Identifying a gap clearly is a real contribution.*
# 3. ***Falsification: what result would convince you to stop?*** *Write down, in advance, the outcome
#    that would tell you this is not worth pursuing -- a resource estimate above some threshold, a
#    classical baseline you cannot beat, an encoding cost that eats the speedup.*
#
# That third question is the one professionals most often skip, and it is the one that saves the most
# time. A plan that cannot be falsified is not a plan.
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# ## What is being assessed
#
# | | |
# |---|---|
# | **Problem and baseline** (§1) | A real problem with a real, named classical baseline and honest cost figures. |
# | **Quantum fit** (§2) | Structure identified and argued, including the strongest counter-argument. A well-supported "poor fit" earns full marks. |
# | **Encoding** (§3) | Two or more options genuinely compared on qubits and depth; the loading bottleneck addressed; a working proof-of-concept cell. |
# | **Algorithm and primitive** (§4) | Choice follows from the structure; Sampler vs Estimator justified; honest about fault-tolerance requirements. |
# | **Simulator vs QPU** (§5) | A staged plan with a defensible shot and QPU budget, and the right noise strategy for the scale. |
# | **Evaluation** (§6) | A concrete baseline, a defined metric, a stated success threshold, and the utility-vs-advantage distinction handled correctly. |
# | **Resources and timeline** (§7) | Estimates that follow from the encoding and algorithm choices, placed honestly on the hardware timeline. |
# | **Literature** (§8) | 3-5 relevant papers, each annotated, with demonstration correctly distinguished from proposal. |
# | **Risks and falsification** (§9) | Real risks, honest gaps, and a falsification criterion stated in advance. |
#
# Throughout, **calibrated honesty outweighs enthusiasm.** The plans that score best are the ones
# whose claims match their evidence.

# %% [markdown]
# ---
# ## Your Work
#
# Use the cells below for any additional code, figures, or notes.
