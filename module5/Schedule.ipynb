# %% [markdown]
# <div style="text-align:center"><img src="../mu_images/idsi_logo.png" alt="MU Institute for Data Science &amp; Informatics" width="280" style="display:inline-block;margin:0 auto"></div>

# %% [markdown]
# # Module 5: Quantum Algorithm Exploration
#
# ## Description
#
# This module surveys algorithms that provide a foundation to the entire field. Shor's algorithm is the reason quantum computing is a risk to current encryption; Deutsch-Jozsa is the clean theoretical case; VQE and QAOA are the near-term variational workhorses for chemistry, materials, and optimization. This is a constantly growing area in research along with quantum applications of these algorithms.
#
# ----

# %% [markdown]
# ## Guiding Questions
#
# Understand the RSA encryption threat from Shor's algorithm, as well as the Deutsch-Jozsa algorithm, VQE for chemistry and material science, and QAOA for optimization.

# %% [markdown]
# ## Topics Covered
#
# - Deutsch-Jozsa algorithm
# - Shor's algorithm and the RSA encryption threat
# - Grover's algorithm and amplitude amplification
# - VQE for chemistry and materials science
# - QAOA for optimization
# - Variational algorithms and the hybrid loop
# - Observables and expectation values
# - Business impacts of quantum algorithms

# %% [markdown]
# ## Objectives
#
# - Students will explain the threat Shor's algorithm poses to RSA and the timeline caveats around it
# - Students will describe the Deutsch-Jozsa speedup and the assumptions it relies on
# - Students will describe the structure of a variational algorithm and the role of the classical optimizer
# - Students will identify candidate problems for VQE and for QAOA
# - Students will compute expectation values of observables from circuit output

# %% [markdown]
# ## Material
#
# 1. [Business Impacts](https://quantum.cloud.ibm.com/learning/en/courses/quantum-business-foundations/business-impacts)
#
# ### Optional (Recommended to pick 1-2 that interest you)
#
# 1. [Shor's Algorithm](https://quantum.cloud.ibm.com/learning/en/courses/fundamentals-of-quantum-algorithms/phase-estimation-and-factoring/shor-algorithm)
# 1. [Shor's Qiskit Notebook](https://quantum.cloud.ibm.com/docs/en/tutorials/shors-algorithm)
# 1. [VQE for chemistry and material science](https://quantum.cloud.ibm.com/learning/en/courses/quantum-diagonalization-algorithms/vqe)
# 1. [QAOA for Optimization](https://quantum.cloud.ibm.com/docs/en/tutorials/quantum-approximate-optimization-algorithm)
# 1. [Fundamentals of Quantum Algorithms](https://quantum.cloud.ibm.com/learning/en/courses/fundamentals-of-quantum-algorithms)
# 1. [Variational Algorithms](https://quantum.cloud.ibm.com/learning/en/courses/variational-algorithm-design/variational-algorithms)

# %% [markdown]
# ## Slides
#
# 1. [Grover’s Algorithm](resources/M5_Grovers_Algorithm_slides.ipynb)

# %% [markdown]
# ## Assignments
#
# 1. [Variational Algorithms: Hamiltonians & Observables Lab](exercises/M5_E1_Variational_Algorithms_Lab.ipynb)

# %% [markdown]
# ## Module Quiz
#
# * [Module 5 Practice Quiz](practices/M5_Quiz.ipynb)
#
# **Course requirement:** you must score **9/10 or higher (90%)** on at least one module's practice quiz. Each quiz draws 10 random questions from a larger bank and tells you the moment you've met the requirement; you can re-roll for a fresh set as often as you like.

# %% [markdown]
# ## IBM Badge Progress
#
# This module counts toward: **Fundamentals of Quantum Algorithms (Week 5)** and **Quantum Business Foundations (Weeks 1, 5, 8)**
#
# Practice exams for these badges:
#
# * [Fundamentals of Quantum Algorithms Practice Exam](../badge_exams/Fundamentals_of_Quantum_Algorithms_Practice_Exam.ipynb)
# * [Quantum Business Foundations Practice Exam](../badge_exams/Quantum_Business_Foundations_Practice_Exam.ipynb)
#
# Badges are earned through IBM Quantum Learning directly. See [Start_Here](../Start_Here.ipynb) for the full badge map and your practice-exam progress.

# %% [markdown]
# ## Submitting Your Work
#
# Be sure you have submitted your assignments for Module 5.
#  * See [Submission of Work](../module1/labs/M1_L3_Committing_Work.ipynb) in Module 1.
#
# It is best practice to create a save point (commit) after each interval of work, e.g., when you are done for the day or you have completed a notebook.
